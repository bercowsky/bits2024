# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read data

# %%
df = pd.read_csv("../data/interim/with_all_indicators.csv")

# %%
df_v2 = pd.read_csv("../data/interim/without_liver_and_blood_indicators.csv")
print(df_v2.nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.read_csv("../data/interim/without_liver_and_blood_indicators.csv")
#       2 print(df.nunique())
#
# NameError: name 'pd' is not defined

# %% [markdown]
# 1. Sex

# %%
sns.countplot(data=df, x='Sex')

plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Barplot of Sex Variable')

plt.show()

# %% [markdown]
# 2. Age at diagnosis

# %%
sns.histplot(data=df, x='Age at diagnosis', bins=20, kde=True)

plt.xlabel('Age at Diagnosis')
plt.ylabel('Frequency')
plt.title('Histogram of Age at Diagnosis')

plt.show()

# %% [markdown]
# 3. Final diagnosis

# %%
sns.countplot(data=df, x='Final diagnosis')

plt.xlabel('Final diagnosis')
plt.ylabel('Count')
plt.title('Barplot of Final diagnosis Variable')

plt.show()

# %% [markdown]
# 4. TOBACCO

# %%
sns.countplot(data=df, x='TOBACCO')

plt.xlabel('TOBACCO')
plt.ylabel('Count')
plt.title('Barplot of TOBACCO Variable')

plt.show()

# %% [markdown]
# 5. Comorbidities

# %%
sns.countplot(data=df, x='Comorbidities')

plt.xlabel('Comorbidities')
plt.ylabel('Count')
plt.title('Barplot of Comorbidities Variable')

plt.show()

# %% [markdown]
# 6. Radiological Pattern

# %%
sns.countplot(data=df, x='Radiological Pattern')

plt.xlabel('Radiological Pattern')
plt.ylabel('Count')
plt.title('Barplot of Radiological Pattern Variable')

plt.show()

# %% [markdown]
# 7. Biopsy

# %%
sns.countplot(data=df, x='Biopsy')

plt.xlabel('Biopsy')
plt.ylabel('Count')
plt.title('Barplot of Biopsy Variable')

plt.show()

# %% [markdown]
# 8. Pathology pattern

# %%
sns.countplot(data=df, x='Pathology pattern')

plt.xlabel('Pathology pattern')
plt.ylabel('Count')
plt.title('Barplot of Pathology pattern Variable')

plt.show()

# %% [markdown]
# 9. Diagnosis after Biopsy

# %%
sns.countplot(data=df, x='Diagnosis after Biopsy')

plt.xlabel('Diagnosis after Biopsy')
plt.ylabel('Count')
plt.title('Barplot of Diagnosis after Biopsy Variable')

plt.show()

# %% [markdown]
# 10. Antifibrotic Drug

# %%
sns.countplot(data=df, x='Antifibrotic Drug')

plt.xlabel('Antifibrotic Drug')
plt.ylabel('Count')
plt.title('Barplot of Antifibrotic Drug Variable')

plt.show()

# %% [markdown]
# 11. Extrapulmonary affectation

# %%
sns.countplot(data=df, x='Extrapulmonary affectation')

plt.xlabel('Extrapulmonary affectation')
plt.ylabel('Count')
plt.title('Barplot of Extrapulmonary affectation Variable')

plt.show()

# %% [markdown]
# 12. Associated lung cancer

# %%
sns.countplot(data=df, x='Associated lung cancer')

plt.xlabel('Associated lung cancer')
plt.ylabel('Count')
plt.title('Barplot of Associated lung cancer Variable')

plt.show()

# %% [markdown]
# 13. Other cancer

# %%
sns.countplot(data=df, x='Other cancer')

plt.xlabel('Other cancer')
plt.ylabel('Count')
plt.title('Barplot of Other cancer Variable')

plt.show()

# %% [markdown]
# 14. Blood count abnormality at diagnosis

# %%
sns.countplot(data=df, x='Blood count abnormality at diagnosis')

plt.xlabel('Blood count abnormality at diagnosis')
plt.ylabel('Count')
plt.title('Barplot of Blood count abnormality at diagnosis Variable')

plt.show()

# %% [markdown]
# 15. Anemia

# %%
sns.countplot(data=df, x='Anemia')

plt.xlabel('Anemia')
plt.ylabel('Count')
plt.title('Barplot of Anemia Variable')

plt.show()

# %% [markdown]
# 16. Thrombocytopenia

# %%
sns.countplot(data=df, x='Thrombocytopenia')

plt.xlabel('Thrombocytopenia')
plt.ylabel('Count')
plt.title('Barplot of Thrombocytopenia Variable')

plt.show()

# %% [markdown]
# 17. Thrombocytosis

# %%
sns.countplot(data=df, x='Thrombocytosis')

plt.xlabel('Thrombocytosis')
plt.ylabel('Count')
plt.title('Barplot of Thrombocytosis Variable')

plt.show()

# %% [markdown]
# 18. Lymphocytosis

# %%
sns.countplot(data=df, x='Lymphocytosis')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Lymphocytosis Variable')

plt.show()

# %% [markdown]
# 19. Lymphopenia

# %%
sns.countplot(data=df, x='Lymphopenia')

plt.xlabel('Lymphopenia')
plt.ylabel('Count')
plt.title('Barplot of Lymphopenia Variable')

plt.show()

# %% [markdown]
# 20. Neutrophilia

# %%
sns.countplot(data=df, x='Neutrophilia')

plt.xlabel('Neutrophilia')
plt.ylabel('Count')
plt.title('Barplot of Neutrophilia Variable')

plt.show()

# %% [markdown]
# 21. Neutropenia

# %%
sns.countplot(data=df, x='Neutropenia')

plt.xlabel('Neutropenia')
plt.ylabel('Count')
plt.title('Barplot of Neutropenia Variable')

plt.show()

# %% [markdown]
# 22. Leukocytosis

# %%
sns.countplot(data=df, x='Leukocytosis')

plt.xlabel('Leukocytosis')
plt.ylabel('Count')
plt.title('Barplot of Leukocytosis Variable')

plt.show()

# %% [markdown]
# 23. Leukopenia

# %%
sns.countplot(data=df, x='Leukopenia')

plt.xlabel('Leukopenia')
plt.ylabel('Count')
plt.title('Barplot of Leukopenia Variable')

plt.show()

# %% [markdown]
# 24. Liver abnormality before diagnosis

# %%
sns.countplot(data=df, x='Liver abnormality before diagnosis')

plt.xlabel('Liver abnormality before diagnosis')
plt.ylabel('Count')
plt.title('Barplot of Liver abnormality before diagnosis Variable')

plt.show()

# %% [markdown]
# 25. Liver abnormality

# %%
sns.countplot(data=df, x='Liver abnormality')

plt.xlabel('Liver abnormality')
plt.ylabel('Count')
plt.title('Barplot of Liver abnormality Variable')

plt.show()

# %% [markdown]
# 26. LDH

# %%
sns.countplot(data=df, x='LDH')

plt.xlabel('LDH')
plt.ylabel('Count')
plt.title('Barplot of LDH Variable')

plt.show()

# %% [markdown]
# 27. ALT

# %%
sns.countplot(data=df, x='ALT')

plt.xlabel('ALT')
plt.ylabel('Count')
plt.title('Barplot of ALT Variable')

plt.show()

# %% [markdown]
# 28. AST

# %%
sns.countplot(data=df, x='AST')

plt.xlabel('AST')
plt.ylabel('Count')
plt.title('Barplot of AST Variable')

plt.show()

# %% [markdown]
# 29. ALP

# %%
sns.countplot(data=df, x='ALP')

plt.xlabel('ALP')
plt.ylabel('Count')
plt.title('Barplot of ALP Variable')

plt.show()

# %% [markdown]
# 30. GGT

# %%
sns.countplot(data=df, x='GGT')

plt.xlabel('GGT')
plt.ylabel('Count')
plt.title('Barplot of GGT Variable')

plt.show()

# %% [markdown]
# 31. Transaminitis

# %%
sns.countplot(data=df, x='Transaminitis')

plt.xlabel('Transaminitis')
plt.ylabel('Count')
plt.title('Barplot of Transaminitis Variable')

plt.show()

# %% [markdown]
# 32. Cholestasis

# %%
sns.countplot(data=df, x='Cholestasis')

plt.xlabel('Cholestasis')
plt.ylabel('Count')
plt.title('Barplot of Cholestasis Variable')

plt.show()

# %% [markdown]
# 33. FVC (%) at diagnosis

# %%
sns.histplot(data=df, x='FVC (%) at diagnosis', bins=20, kde=True)

plt.xlabel('FVC (%) at diagnosis')
plt.ylabel('Frequency')
plt.title('Histogram of FVC (%) at diagnosis')

plt.show()

# %% [markdown]
# 34. DLCO (%) at diagnosis

# %%
sns.histplot(data=df, x='DLCO (%) at diagnosis', bins=20, kde=True)

plt.xlabel('DLCO (%) at diagnosis')
plt.ylabel('Frequency')
plt.title('Histogram of DLCO (%) at diagnosis')

plt.show()

# %% [markdown]
# 35. FVC (%) 1 year after diagnosis

# %%
sns.histplot(data=df, x='FVC (%) 1 year after diagnosis', bins=20, kde=True)

plt.xlabel('FVC (%) 1 year after diagnosis')
plt.ylabel('Frequency')
plt.title('Histogram of FVC (%) 1 year after diagnosis')

plt.show()

# %% [markdown]
# 36. DLCO (%) 1 year after diagnosis

# %%
sns.histplot(data=df, x='DLCO (%) 1 year after diagnosis', bins=20, kde=True)

plt.xlabel('DLCO (%) 1 year after diagnosis')
plt.ylabel('Frequency')
plt.title('Histogram of DLCO (%) 1 year after diagnosis')

plt.show()

# %% [markdown]
# 37. RadioWorsening2y

# %%
sns.countplot(data=df, x='Lymphocytosis')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Lymphocytosis Variable')

plt.show()

# %% [markdown]
# 38. 1st degree relative

# %%
sns.countplot(data=df, x='Lymphocytosis')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Lymphocytosis Variable')

plt.show()

# %% [markdown]
# 39. 2nd degree relative

# %%
sns.countplot(data=df, x='Lymphocytosis')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Lymphocytosis Variable')

plt.show()

# %% [markdown]
# 40. More than 1 relative

# %%
sns.countplot(data=df, x='Lymphocytosis')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Lymphocytosis Variable')

plt.show()

# %% [markdown]
# 41. Mutation Type

# %%
sns.countplot(data=df, x='Mutation Type')

plt.xlabel('Mutation Type')
plt.ylabel('Count')
plt.title('Barplot of Mutation Type')

plt.show()

# %% [markdown]
# 42. Severity of telomere shortening - Transform 4

# %%
sns.countplot(data=df, x='Severity of telomere shortening - Transform 4')

plt.xlabel('Severity of telomere shortening - Transform 4')
plt.ylabel('Count')
plt.title('Barplot of Severity of telomere shortening - Transform 4 Variable')

plt.show()

# %% [markdown]
# 43. Anti-inflammatory drug

# %%
sns.countplot(data=df, x='Anti-inflammatory drug')

plt.xlabel('Lymphocytosis')
plt.ylabel('Count')
plt.title('Barplot of Anti-inflammatory drug Variable')

plt.show()

# %% [markdown]
# 44. Severity of telomere shortening

# %%
sns.countplot(data=df, x='Severity of telomere shortening')

plt.xlabel('Severity of telomere shortening')
plt.ylabel('Count')
plt.title('Barplot of Severity of telomere shortening Variable')

plt.show()

# %% [markdown]
# 45. target

# %%
sns.countplot(data=df, x='target')

plt.xlabel('target')
plt.ylabel('Count')
plt.title('Barplot of target Variable')

plt.show()
