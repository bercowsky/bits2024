# %% [markdown]
# # Data exploration

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Read Data

# %% [markdown]
# Read raw csv file

# %%
df = pd.read_csv("../data/raw_csv/FibroPredCODIFICADA.csv")

unique_values = {column: df[column].unique() for column in df.columns}

# Print the unique values for each column
for column, values in unique_values.items():
    print(f"Column: {column}")
    print(f"Unique values: {values[:3]}")  # Print only the first 10 unique values for brevity
    print("------")
# Out:
# Column: Pedigree
# Unique values: [1 2 3]
# ------
# Column: Sex
# Unique values: ['Male' 'Female']
# ------
# Column: FamilialvsSporadic
# Unique values: ['Familial' 'Sporadic']
# ------
# Column: COD NUMBER
# Unique values: ['13820545' '12974225' '13551148']
# ------
# Column: Age at diagnosis
# Unique values: [70. 66. 59.]
# ------
# Column: Binary diagnosis
# Unique values: ['No IPF' 'IPF']
# ------
# Column: Final diagnosis
# Unique values: [3 8 1]
# ------
# Column: TOBACCO
# Unique values: [2 0 1]
# ------
# Column: Detail
# Unique values: ['Tobacco-associated' nan 'Organizing']
# ------
# Column: Comorbidities
# Unique values: [0 1]
# ------
# Column: Radiological Pattern
# Unique values: ['UIP' 'Probable UIP' 'Non UIP']
# ------
# Column: Detail on NON UIP
# Unique values: [nan 'Fibrosing Organizing Pneumonia' 'Emphysema']
# ------
# Column: Biopsy
# Unique values: [0. 1. 2.]
# ------
# Column: Pathology Pattern Binary
# Unique values: [nan 'NON UIP' 'UIP']
# ------
# Column: Pathology pattern UIP, probable or CHP
# Unique values: [nan 'UIP' 'Probable UIP']
# ------
# Column: Pathology pattern
# Unique values: ['0' 'Necrotizing vasculitis' 'UIP']
# ------
# Column: Extras AP
# Unique values: [nan 'Organizativa' 'Metaplasia osea']
# ------
# Column: Diagnosis after Biopsy
# Unique values: [-9.  1.  0.]
# ------
# Column: Multidsciplinary committee
# Unique values: [ 1.  0. nan]
# ------
# Column: Pirfenidone
# Unique values: [1 0]
# ------
# Column: Nintedanib
# Unique values: [0 1]
# ------
# Column: Antifibrotic Drug
# Unique values: [1 0]
# ------
# Column: Prednisone
# Unique values: [0 1]
# ------
# Column: Mycophenolate
# Unique values: [0 1]
# ------
# Column: Treatment
# Unique values: ['Pirfenidone' 'Pirfenidone, Prednisone, MMF, Rituximab, Tacrolimus'
#  'Nintedanib, Pirfenidone']
# ------
# Column: Extrapulmonary affectation
# Unique values: [ 0.  1. nan]
# ------
# Column: Type of telomeric extrapulmonary affectation
# Unique values: [nan 'Neutrophilia, Lymphopenia' 'Thalassemia']
# ------
# Column: Extra
# Unique values: [nan 'Central core myopathy' 'Facioscapulohumeral muscular dystrophy']
# ------
# Column: Associated lung cancer
# Unique values: [ 0.  1. nan]
# ------
# Column: Other cancer
# Unique values: [ 0.  1. nan]
# ------
# Column: Type of neoplasia
# Unique values: [nan 'Kaposi Sarcoma' 'Lung ADK']
# ------
# Column: Hematological abnormality before diagnosis
# Unique values: [nan 'Yes']
# ------
# Column: Blood count abnormality at diagnosis
# Unique values: [ 0.  1. nan]
# ------
# Column: Anemia
# Unique values: [ 0.  1. nan]
# ------
# Column: Thrombocytopenia
# Unique values: [ 0.  1. nan]
# ------
# Column: Thrombocytosis
# Unique values: [ 0.  1. nan]
# ------
# Column: Lymphocytosis
# Unique values: [ 0.  1. nan]
# ------
# Column: Lymphopenia
# Unique values: [ 0.  1. nan]
# ------
# Column: Neutrophilia
# Unique values: [ 0.  1. nan]
# ------
# Column: Neutropenia
# Unique values: [ 0. nan]
# ------
# Column: Leukocytosis
# Unique values: [ 0.  1. nan]
# ------
# Column: Leukopenia
# Unique values: [ 0.  1. nan]
# ------
# Column: Hematologic Disease
# Unique values: ['No' 'Thalassemia' 'Yes']
# ------
# Column: Liver abnormality before diagnosis
# Unique values: ['Yes' 'No' nan]
# ------
# Column: Liver abnormality
# Unique values: ['Yes' 'No' nan]
# ------
# Column: LDH
# Unique values: [1 0]
# ------
# Column: ALT
# Unique values: [0 1]
# ------
# Column: AST
# Unique values: [0 1]
# ------
# Column: ALP
# Unique values: [0 1]
# ------
# Column: GGT
# Unique values: [0 1]
# ------
# Column: Transaminitis
# Unique values: [0 1]
# ------
# Column: Cholestasis
# Unique values: [0 1]
# ------
# Column: Type of liver abnormality
# Unique values: ['LDH' 'LDH, ALT, AST, GGT' 'LDH, AST, ALT, FA, GGT']
# ------
# Column: Liver disease
# Unique values: ['No' 'Liver cirrhosis' 'Fatty liver disease']
# ------
# Column: FVC (L) at diagnosis
# Unique values: [2.95 2.84 2.56]
# ------
# Column: FVC (%) at diagnosis
# Unique values: [79.9 75.4 83.8]
# ------
# Column: DLCO (%) at diagnosis
# Unique values: [43.4 48.1 32.6]
# ------
# Column: FVC (L) 1 year after diagnosis
# Unique values: [2.67 2.76 2.91]
# ------
# Column: FVC (%) 1 year after diagnosis
# Unique values: [67.  53.  88.4]
# ------
# Column: DLCO (%) 1 year after diagnosis
# Unique values: [27.  53.  28.4]
# ------
# Column: RadioWorsening2y
# Unique values: [1. 0. 3.]
# ------
# Column: Necessity of transplantation
# Unique values: [ 0.  1. nan]
# ------
# Column: Transplantation date
# Unique values: ['No transplantation' '12/22/2020' '5/13/2010']
# ------
# Column: Death
# Unique values: ['Yes' 'No' nan]
# ------
# Column: Cause of death
# Unique values: ['Respiratory excerbation' 'No death' 'Lung fibrosis progression']
# ------
# Column: Identified Infection
# Unique values: [nan 'HIV+CMV+' 'Influenza A']
# ------
# Column: Date of death
# Unique values: ['7/10/2018' 'Not dead' '1/11/2018']
# ------
# Column: Type of family history
# Unique values: ['CPFE' 'Unspecified PF' nan]
# ------
# Column: 1st degree relative
# Unique values: [1 0]
# ------
# Column: 2nd degree relative
# Unique values: [0 1]
# ------
# Column: More than 1 relative
# Unique values: [0 1]
# ------
# Column: Genetic mutation studied in patient
# Unique values: [ 1.  0. -9.]
# ------
# Column: Mutation Type
# Unique values: [nan 'TERT Exon 2b/HT/c.835G>A / p.Ala279Thr/ rs61748181' 'TERT']
# ------
# Column: Severity of telomere shortening
# Unique values: [3. 1. 4.]
# ------
# Column: Severity of telomere shortening - Transform 4
# Unique values: [6. 4. 3.]
# ------
# Column: Progressive disease
# Unique values: [ 1.  0. nan]
# ------
# Column: ProgressiveDisease
# Unique values: [ 1.  0. nan]
# ------

# %% [markdown]
# General statistics

# %%
rows, columns = df.shape
print(f"Number of rows {rows}. Number of columns {columns}")
df.describe()
# Out:
# Number of rows 222. Number of columns 77
#          Pedigree  Age at diagnosis  Final diagnosis     TOBACCO  \
# count  222.000000        221.000000       222.000000  222.000000
# mean    14.585586         66.506787         3.626126    1.166667
# std     20.503600         10.046990         3.473213    0.981349
# min      0.000000         36.000000         1.000000    0.000000
# 25%      0.000000         62.000000         1.000000    0.000000
# 50%      0.000000         68.000000         1.000000    2.000000
# 75%     25.750000         73.000000         6.000000    2.000000
# max     67.000000         92.000000        18.000000    2.000000
#
#        Comorbidities      Biopsy  Diagnosis after Biopsy  \
# count     222.000000  219.000000              221.000000
# mean        0.738739    0.479452               -5.031674
# std         0.440315    0.608267                4.848982
# min         0.000000    0.000000               -9.000000
# 25%         0.000000    0.000000               -9.000000
# 50%         1.000000    0.000000               -9.000000
# 75%         1.000000    1.000000                1.000000
# max         1.000000    2.000000                1.000000
#
#        Multidsciplinary committee  Pirfenidone  Nintedanib  ...  \
# count                  221.000000   222.000000  222.000000  ...
# mean                     0.846154     0.301802    0.324324  ...
# std                      0.361620     0.460077    0.469180  ...
# min                      0.000000     0.000000    0.000000  ...
# 25%                      1.000000     0.000000    0.000000  ...
# 50%                      1.000000     0.000000    0.000000  ...
# 75%                      1.000000     1.000000    1.000000  ...
# max                      1.000000     1.000000    1.000000  ...
#
#        RadioWorsening2y  Necessity of transplantation  1st degree relative  \
# count        220.000000                    220.000000           222.000000
# mean           0.450000                      0.150000             0.441441
# std            0.722913                      0.357886             0.497681
# min            0.000000                      0.000000             0.000000
# 25%            0.000000                      0.000000             0.000000
# 50%            0.000000                      0.000000             0.000000
# 75%            1.000000                      0.000000             1.000000
# max            3.000000                      1.000000             1.000000
#
#        2nd degree relative  More than 1 relative  \
# count           222.000000            222.000000
# mean              0.081081              0.220721
# std               0.273576              0.415670
# min               0.000000              0.000000
# 25%               0.000000              0.000000
# 50%               0.000000              0.000000
# 75%               0.000000              0.000000
# max               1.000000              1.000000
#
#        Genetic mutation studied in patient  Severity of telomere shortening  \
# count                           202.000000                       152.000000
# mean                              0.366337                         2.703947
# std                               0.825258                         1.982836
# min                              -9.000000                        -9.000000
# 25%                               0.000000                         1.000000
# 50%                               0.000000                         3.000000
# 75%                               1.000000                         4.000000
# max                               1.000000                         6.000000
#
#        Severity of telomere shortening - Transform 4  Progressive disease  \
# count                                     149.000000           212.000000
# mean                                        3.885906             0.457547
# std                                         1.276239             0.499374
# min                                         1.000000             0.000000
# 25%                                         3.000000             0.000000
# 50%                                         4.000000             0.000000
# 75%                                         5.000000             1.000000
# max                                         6.000000             1.000000
#
#        ProgressiveDisease
# count          212.000000
# mean             0.457547
# std              0.499374
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000
#
# [8 rows x 49 columns]

# %% [markdown]
# ## 2. Data cleaning

# %% [markdown]
# Check if Progressive disease = ProgressiveDisease

# %%
distinct_rows = df[df['Progressive disease'] != df['ProgressiveDisease']]
row_count = distinct_rows.shape[0]
print(f"The number of rows where 'Progressive disease' and 'ProgressiveDisease' are distinct is {row_count}.")
# Out:
# The number of rows where 'Progressive disease' and 'ProgressiveDisease' are distinct is 10.

# %% [markdown]
# Delete ProgressiveDisease

# %%
df = df.drop("ProgressiveDisease", axis=1)

# %% [markdown]
# Delte COD NUMBER variable

# %%
# Count of unique values
df['COD NUMBER'][df['COD NUMBER'].duplicated()]

# Delete COD NUMBER variable
df = df.drop("COD NUMBER", axis=1)

# %% [markdown]
# Clean target variable

# %%
df_new = df[df['Progressive disease'].isnull()]

row_count = df_new.shape[0]
print(f"Number of null target variable rows {row_count}")

print(df_new[['Death', 'Transplantation date']])
df_new.describe()
# Out:
# Number of null target variable rows 10
#     Death Transplantation date
# 22     No   No transplantation
# 48     No   No transplantation
# 49     No   No transplantation
# 50     No   No transplantation
# 54     No   No transplantation
# 73     No   No transplantation
# 74     No   No transplantation
# 77     No   No transplantation
# 129   NaN                  NaN
# 130   NaN                  NaN
#         Pedigree  Age at diagnosis  Final diagnosis    TOBACCO  Comorbidities  \
# count  10.000000         10.000000        10.000000  10.000000      10.000000
# mean   26.400000         64.300000         4.000000   1.000000       0.700000
# std    17.620695          8.615877         5.537749   1.054093       0.483046
# min     0.000000         51.000000         1.000000   0.000000       0.000000
# 25%    16.250000         62.000000         1.000000   0.000000       0.250000
# 50%    27.500000         63.500000         1.000000   1.000000       1.000000
# 75%    41.500000         69.250000         3.500000   2.000000       1.000000
# max    48.000000         81.000000        17.000000   2.000000       1.000000
#
#           Biopsy  Diagnosis after Biopsy  Multidsciplinary committee  \
# count  10.000000                9.000000                    9.000000
# mean    0.500000               -5.666667                    0.888889
# std     0.527046                5.000000                    0.333333
# min     0.000000               -9.000000                    0.000000
# 25%     0.000000               -9.000000                    1.000000
# 50%     0.500000               -9.000000                    1.000000
# 75%     1.000000                1.000000                    1.000000
# max     1.000000                1.000000                    1.000000
#
#        Pirfenidone  Nintedanib  ...  DLCO (%) 1 year after diagnosis  \
# count         10.0   10.000000  ...                         8.000000
# mean           0.0    0.500000  ...                        58.140000
# std            0.0    0.527046  ...                        15.223185
# min            0.0    0.000000  ...                        22.120000
# 25%            0.0    0.000000  ...                        57.750000
# 50%            0.0    0.500000  ...                        62.500000
# 75%            0.0    1.000000  ...                        65.750000
# max            0.0    1.000000  ...                        70.000000
#
#        RadioWorsening2y  Necessity of transplantation  1st degree relative  \
# count           8.00000                           8.0            10.000000
# mean            2.62500                           0.0             0.800000
# std             1.06066                           0.0             0.421637
# min             0.00000                           0.0             0.000000
# 25%             3.00000                           0.0             1.000000
# 50%             3.00000                           0.0             1.000000
# 75%             3.00000                           0.0             1.000000
# max             3.00000                           0.0             1.000000
#
#        2nd degree relative  More than 1 relative  \
# count            10.000000             10.000000
# mean              0.300000              0.500000
# std               0.483046              0.527046
# min               0.000000              0.000000
# 25%               0.000000              0.000000
# 50%               0.000000              0.500000
# 75%               0.750000              1.000000
# max               1.000000              1.000000
#
#        Genetic mutation studied in patient  Severity of telomere shortening  \
# count                              8.00000                         8.000000
# mean                               0.75000                         1.500000
# std                                0.46291                         0.755929
# min                                0.00000                         1.000000
# 25%                                0.75000                         1.000000
# 50%                                1.00000                         1.000000
# 75%                                1.00000                         2.000000
# max                                1.00000                         3.000000
#
#        Severity of telomere shortening - Transform 4  Progressive disease
# count                                       8.000000                  0.0
# mean                                        4.500000                  NaN
# std                                         0.755929                  NaN
# min                                         4.000000                  NaN
# 25%                                         4.000000                  NaN
# 50%                                         4.000000                  NaN
# 75%                                         5.000000                  NaN
# max                                         6.000000                  NaN
#
# [8 rows x 48 columns]

# %% [markdown]
# Keep only not null target variables

# %%
df = df[df['Progressive disease'].notnull()]
print(df.shape)
# Out:
# (212, 75)

# %% [markdown]
# Columns with high null values

# %%
# Set threshold for "high percentage" of null values
threshold = 50

# Percentage of null values
null_percentage = df.isnull().mean() * 100

# Filter columns with null percentage above threshold
high_null_columns = null_percentage[null_percentage > threshold]

print(f"Columns with high percentage of null values {high_null_columns}")
# Out:
# Columns with high percentage of null values Detail                                          69.811321
# Detail on NON UIP                               74.056604
# Pathology Pattern Binary                        57.075472
# Pathology pattern UIP, probable or CHP          61.320755
# Extras AP                                       84.433962
# Type of telomeric extrapulmonary affectation    86.320755
# Extra                                           98.584906
# Type of neoplasia                               85.377358
# Hematological abnormality before diagnosis      87.264151
# Type of liver abnormality                       71.698113
# Identified Infection                            97.169811
# Mutation Type                                   89.150943
# dtype: float64

# %% [markdown]
# Delete varialbes with high nulls

# %%
list_drop = ['Extra', 'Identified Infection']
df = df.drop(list_drop, axis=1)

# %% [markdown]
# Transform Mutation Type variable

# %%
df['Mutation Type'] = df.apply(
    lambda row: 'No' if row['Genetic mutation studied in patient'] == 1 and pd.isnull(row['Mutation Type']) else 
                ('Yes' if row['Genetic mutation studied in patient'] == 1 and pd.notnull(row['Mutation Type']) else
                 'Not Investigated'), axis=1)

# %% [markdown]
# Create Anti-inflammatory drug variable

# %%
df['Anti-inflammatory drug'] = ((df['Prednisone'] == 1) | (df['Mycophenolate'] == 1)).astype(int)

# %% [markdown]
# Delete non-explanatory variables

# %%
list_drop = ['Pathology pattern UIP, probable or CHP', 'Pathology Pattern Binary', 'FamilialvsSporadic', 
             'Type of liver abnormality', 'Necessity of transplantation', 'Genetic mutation studied in patient',
             'Detail', 'Pirfenidone', 'Nintedanib', 'Treatment', 'Prednisone', 'Mycophenolate', 
             'Type of telomeric extrapulmonary affectation', 'Liver disease', 'Pedigree', 'Multidsciplinary committee', 
             'FVC (L) at diagnosis', 'FVC (L) 1 year after diagnosis', 'Extras AP', 'Type of neoplasia', 
             'Hematological abnormality before diagnosis', 'Hematologic Disease', 'Detail on NON UIP',
             'Date of death', 'Cause of death', 'Type of family history', 'Binary diagnosis',
             'Severity of telomere shortening - Transform 4']

df = df.drop(list_drop, axis=1)

# %% [markdown]
# Binarize Transplantation date and Death variables

# %%
# Transform 'Transplantation date' into binary
df['Transplantation date_binary'] = df['Transplantation date'].apply(lambda x: 1 if x != 'No transplantation' else 0)
null_transplantation = df[df['Transplantation date_binary'].isnull()]

# Transform 'Death' into binary
df['Death_binary'] = df['Death'].apply(lambda x: 1 if x == "Yes" else 0)
null_death = df[df['Death_binary'].isnull()]

# %% [markdown]
# Combine Transplatation date, Death and target variable

# %%
df['target'] = ((df['Transplantation date_binary'] == 1) | 
                (df['Death_binary'] == 1) | 
                (df['Progressive disease'] == 1)).astype(int)

list_drop = ['Transplantation date', 'Progressive disease', 
             'Death', 'Death_binary', 'Transplantation date_binary']
df = df.drop(list_drop, axis=1)

# %% [markdown]
# ## 3. Data inspection of cleaned data

# %% [markdown]
# Basic information of the cleaned dataset

# %%
print(f"Shape of the dataset {df.shape}")
print(f"Basic statistics {df.describe()}")
# Out:
# Shape of the dataset (212, 44)
# Basic statistics        Age at diagnosis  Final diagnosis     TOBACCO  Comorbidities  \
# count        211.000000       212.000000  212.000000     212.000000
# mean          66.611374         3.608491    1.174528       0.740566
# std           10.115554         3.364510    0.979753       0.439362
# min           36.000000         1.000000    0.000000       0.000000
# 25%           62.000000         1.000000    0.000000       0.000000
# 50%           68.000000         1.000000    2.000000       1.000000
# 75%           73.000000         6.000000    2.000000       1.000000
# max           92.000000        18.000000    2.000000       1.000000
#
#            Biopsy  Diagnosis after Biopsy  Antifibrotic Drug  \
# count  209.000000              212.000000         212.000000
# mean     0.478469               -5.004717           0.589623
# std      0.612973                4.852808           0.493066
# min      0.000000               -9.000000           0.000000
# 25%      0.000000               -9.000000           0.000000
# 50%      0.000000               -9.000000           1.000000
# 75%      1.000000                1.000000           1.000000
# max      2.000000                1.000000           1.000000
#
#        Extrapulmonary affectation  Associated lung cancer  Other cancer  ...  \
# count                  210.000000              211.000000    211.000000  ...
# mean                     0.138095                0.042654      0.109005  ...
# std                      0.345824                0.202556      0.312386  ...
# min                      0.000000                0.000000      0.000000  ...
# 25%                      0.000000                0.000000      0.000000  ...
# 50%                      0.000000                0.000000      0.000000  ...
# 75%                      0.000000                0.000000      0.000000  ...
# max                      1.000000                1.000000      1.000000  ...
#
#        DLCO (%) at diagnosis  FVC (%) 1 year after diagnosis  \
# count             212.000000                       210.00000
# mean               59.629245                        81.51619
# std                21.726449                        21.96467
# min                18.900000                        28.00000
# 25%                44.000000                        67.00000
# 50%                57.550000                        81.50000
# 75%                71.375000                        97.20000
# max               145.000000                       143.10000
#
#        DLCO (%) 1 year after diagnosis  RadioWorsening2y  1st degree relative  \
# count                       208.000000        212.000000           212.000000
# mean                         56.841538          0.367925             0.424528
# std                          22.010423          0.564771             0.495441
# min                          -9.000000          0.000000             0.000000
# 25%                          39.875000          0.000000             0.000000
# 50%                          56.000000          0.000000             0.000000
# 75%                          69.100000          1.000000             1.000000
# max                         128.010000          3.000000             1.000000
#
#        2nd degree relative  More than 1 relative  \
# count           212.000000            212.000000
# mean              0.070755              0.207547
# std               0.257022              0.406511
# min               0.000000              0.000000
# 25%               0.000000              0.000000
# 50%               0.000000              0.000000
# 75%               0.000000              0.000000
# max               1.000000              1.000000
#
#        Severity of telomere shortening  Anti-inflammatory drug      target
# count                       144.000000              212.000000  212.000000
# mean                          2.770833                0.377358    0.471698
# std                           2.009484                0.485873    0.500380
# min                          -9.000000                0.000000    0.000000
# 25%                           1.000000                0.000000    0.000000
# 50%                           3.000000                0.000000    0.000000
# 75%                           4.000000                1.000000    1.000000
# max                           6.000000                1.000000    1.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# Check null values

# %%
# Set threshold for null values
threshold = 0

# Percentage of null values
null_percentage = df.isnull().mean() * 100

# Filter columns with null percentage above threshold
high_null_columns = null_percentage[null_percentage > threshold]

print(f"Columns with high percentage of null values {high_null_columns}")
# Out:
# Columns with high percentage of null values Age at diagnosis                         0.471698
# Biopsy                                   1.415094
# Pathology pattern                        1.886792
# Extrapulmonary affectation               0.943396
# Associated lung cancer                   0.471698
# Other cancer                             0.471698
# Blood count abnormality at diagnosis     0.943396
# Anemia                                   0.471698
# Thrombocytopenia                         0.471698
# Leukocytosis                             0.471698
# Leukopenia                               0.943396
# Liver abnormality before diagnosis       8.962264
# FVC (%) 1 year after diagnosis           0.943396
# DLCO (%) 1 year after diagnosis          1.886792
# Severity of telomere shortening         32.075472
# dtype: float64

# %% [markdown]
# Save dataset

# %%
df.to_csv('../data/interim/with_all_indicators.csv', index=False)

# %% [markdown]
# ## 4. Datasets without specific indicators:
#
# 1. **Dataset without liver indicators info**:
#
# 2. **Dataset without blood indicators info**:
#
# 3. **Dataset without both liver and blood indicators info**:

# %%
liver_drop = ['LDH', 'ALT', 'AST', 'ALP', 'GGT', 'Transaminitis', 'Cholestasis']
blood_drop = ['Anemia', 'Thrombocytopenia', 'Thrombocytosis', 'Lymphocytosis', 'Lymphopenia',
              'Neutrophilia', 'Neutropenia', 'Leukocytosis', 'Leukopenia']

df_no_liver = df.drop(liver_drop, axis=1)
df_no_blood = df.drop(blood_drop, axis=1)
df_no_liver_blood = df.drop(liver_drop+blood_drop, axis=1)

# %% [markdown]
# Shapes of each dataset.

# %%
print(f"Number of columns without liver indicators {df_no_liver.shape}")
print(f"Number of columns without blood indicators {df_no_blood.shape}")
print(f"Number of columns without liver and blood indicators {df_no_liver_blood.shape}")
# Out:
# Number of columns without liver indicators (212, 37)
# Number of columns without blood indicators (212, 35)
# Number of columns without liver and blood indicators (212, 28)

# %% [markdown]
# Save this datasets.

# %%
df_no_liver.to_csv('../data/interim/without_liver_indicators.csv', index=False)
df_no_blood.to_csv('../data/interim/without_blood_indicators.csv', index=False)
df_no_liver_blood.to_csv('../data/interim/without_liver_and_blood_indicators.csv', index=False)
